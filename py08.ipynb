# %% [markdown]
# # 외부 라이브러리

# %% [markdown]
# ## pip *
# - venv1 생성 후 백업 : pip freeze > requirements.txt
# - venv
# - s
# - venv4에 pip리스트
# - venv5에 numpy 2.2.2 버전으로 복구되도록 requirements.txt 수정 후 복구하라

# %% [markdown]
# ## Faker

# %%
# !pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-36.1.1-py3-none-any.whl.metadata (15 kB)
# Collecting tzdata (from Faker)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading Faker-36.1.1-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 27.4 MB/s eta 0:00:00
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, Faker
# Successfully installed Faker-36.1.1 tzdata-2025.1

# %%
from faker import Faker
fake = Faker('ko-KR')
[{"name" : fake.name(), "company" : fake.company(), "phone" : fake.phone_number(), "email" : fake.email()} for n in range(10)]
# Out:
# [{'name': '홍은영',
#   'company': '김안황',
#   'phone': '055-211-1461',
#   'email': 'gimyejin@example.org'},
#  {'name': '이지민',
#   'company': '(주) 박',
#   'phone': '02-4720-3936',
#   'email': 'jiyeoni@example.org'},
#  {'name': '심유진',
#   'company': '주식회사 이박윤',
#   'phone': '017-870-4569',
#   'email': 'hi@example.org'},
#  {'name': '류유진',
#   'company': '유한회사 우',
#   'phone': '017-468-7201',
#   'email': 'gimmisug@example.com'},
#  {'name': '김광수',
#   'company': '장박김',
#   'phone': '041-892-8225',
#   'email': 'rgim@example.org'},
#  {'name': '백승민',
#   'company': '(주) 박김박',
#   'phone': '018-673-8240',
#   'email': 'sangho81@example.net'},
#  {'name': '김준호',
#   'company': '허김김',
#   'phone': '016-279-5530',
#   'email': 'coeseongmin@example.com'},
#  {'name': '송영미',
#   'company': '박이이',
#   'phone': '010-7015-2622',
#   'email': 'jihungim@example.net'},
#  {'name': '김채원',
#   'company': '윤이이',
#   'phone': '061-162-4408',
#   'email': 'yeongjin02@example.com'},
#  {'name': '이성민',
#   'company': '(주) 엄',
#   'phone': '043-700-8199',
#   'email': 'minjungim@example.net'}]

# %% [markdown]
# <table style = "float:left;width:400px">
# <thead>
# <tr>
# <th>항목</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>fake.name()</td>
# <td>이름</td>
# </tr>
# <tr>
# <td>fake.address()</td>
# <td>주소</td>
# </tr>
# <tr>
# <td>fake.postcode()</td>
# <td>우편 번호</td>
# </tr>
# <tr>
# <td>fake.country()</td>
# <td>국가명</td>
# </tr>
# <tr>
# <td>fake.company()</td>
# <td>회사명</td>
# </tr>
# <tr>
# <td>fake.job()</td>
# <td>직업명</td>
# </tr>
# <tr>
# <td>fake.phone_number()</td>
# <td>휴대전화 번호</td>
# </tr>
# <tr>
# <td>fake.email()</td>
# <td>이메일 주소</td>
# </tr>
# <tr>
# <td>fake.user_name()</td>
# <td>사용자명</td>
# </tr>
# <tr>
# <td>fake.pyint(min_value=0, max_value=100)</td>
# <td>0부터 100 사이의 임의의 숫자</td>
# </tr>
# <tr>
# <td>fake.ipv4_private()</td>
# <td>IP 주소</td>
# </tr>
# <tr>
# <td>fake.text()</td>
# <td>임의의 문장 (한글 임의의 문장은 <code>fake.catch_phrase()</code> 사용)</td>
# </tr>
# <tr>
# <td>fake.color_name()</td>
# <td>색상명</td>
# </tr>
# </tbody>
# </table>

# %%
from fractions import Fraction
import sympy

x = sympy.symbols("x")
f = sympy.Eq(x * Fraction('2 / 5'), 1760)
result = sympy.solve(f)
remains = result[0] - 1760
print('남은 돈은 {}원 입니다.'.format(remains))
# Out:
# 남은 돈은 2640원 입니다.

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.melon.com/chart/index.htm"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

title = soup.select('.rank01')[:20]
name = soup.select('.checkEllipsis a')
str = ''
for i, (t, n) in enumerate(zip(title, name), 1):
    str += f'{i}위 : {t.text.strip()} / {n.text}\n'
print(str, end=' ')
# Out:
# 1위 : REBEL HEART / IVE (아이브)
# 2위 : HOME SWEET HOME (feat. 태양, 대성) / G-DRAGON
# 3위 : 나는 반딧불 / 황가람
# 4위 : Whiplash / aespa
# 5위 : APT. / 로제 (ROSÉ)
# 6위 : Drowning / Bruno Mars
# 7위 : 오늘만 I LOVE YOU / WOODZ
# 8위 : ATTITUDE / BOYNEXTDOOR
# 9위 : toxic till the end / IVE (아이브)
# 10위 : Dash / 로제 (ROSÉ)
# 11위 : POWER / PLAVE
# 12위 : HAPPY / G-DRAGON
# 13위 : 내게 사랑이 뭐냐고 물어본다면 / DAY6 (데이식스)
# 14위 : DRIP / 로이킴
# 15위 : RIZZ / BABYMONSTER
# 16위 : Chroma Drift / PLAVE
# 17위 : 소나기 / PLAVE
# 18위 : Island / 이클립스 (ECLIPSE)
# 19위 : 너와의 모든 지금 / PLAVE
# 20위 : 모르시나요(PROD.로코베리) / 재쓰비 (JAESSBEE)

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html5lib')

menucard = soup.select('.menu-tbl')
won = soup.select('.menu-tit01')
menu = soup.select('h3.menu-tit01+p')
day = soup.select('.day')
date = soup.select('.date')
for d, dd, w, m in zip(day, date, won, menu):
    print('=' * 15)
    print(d.text + '\n' + dd.text)
    print('=' * 15)
    print(w.text + '\n' + m.text)
# Out:
# ===============
# 월
# 2025.02.17
# ===============
# 정식-5,500원
# 강황밥
# 김치콩나물국
# 돈육바싹불고기
# 모듬잡채
# 멸치새우견과볶음
# 상추겉절이
# 포기김치
#
# ===============
# 화
# 2025.02.18
# ===============
# 정식-5,500원
# 백미밥
# 물만두국
# 순살닭매콤조림
# 쫄면야채무침
# 파래무무침
# 참나물겉절이
# 포기김치
#
# ===============
# 수
# 2025.02.19
# ===============
# 정식-5,500원
# 백미밥
# 모듬어묵국
# 함박스테이크/치즈/소스
# 스파게티/소스
# 치커리유자청샐러드
# 콩나물무침
# 포기김치
#
# ===============
# 목
# 2025.02.20
# ===============
# 정식-5,500원
# 잡곡밥
# 홍합미역국
# 순살치킨/맛초킹소스
# 꼬시레기두부무침
# 잡채어묵조림
# 상추겉절이
# 포기김치
#
# ===============
# 금
# 2025.02.21
# ===============
# 정식-5,500원
# 백미밥
# 국수
# 깐풍기/소스
# 알감자버터구이
# 도토리묵김치무침
# 열무겉절이
# 포기김치

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://finance.naver.com/sise/sise_market_sum.naver"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

comp = soup.select('.tltle')
won = soup.select('.number:nth-child(3)')
for c, w in zip(comp, won):
    print(c.text + ':' + w.text + '원')
# Out:
# 삼성전자:58,200원
# SK하이닉스:216,500원
# LG에너지솔루션:371,500원
# 삼성바이오로직스:1,140,000원
# 현대차:201,500원
# 삼성전자우:49,050원
# 셀트리온:180,900원
# 기아:93,700원
# NAVER:219,500원
# KB금융:82,400원
# 한화에어로스페이스:618,000원
# HD현대중공업:315,500원
# 신한지주:47,350원
# 메리츠금융지주:123,500원
# 삼성물산:132,100원
# 현대모비스:250,000원
# 한화오션:72,900원
# POSCO홀딩스:262,500원
# 삼성생명:100,700원
# SK이노베이션:130,600원
# 삼성화재:404,500원
# 두산에너빌리티:28,650원
# 하나금융지주:62,300원
# 카카오:39,900원
# LG화학:247,000원
# 고려아연:829,000원
# HMM:18,660원
# 크래프톤:332,500원
# HD한국조선해양:221,500원
# 삼성SDI:226,500원
# 한국전력:21,500원
# SK스퀘어:102,500원
# HD현대일렉트릭:377,500원
# LG전자:81,900원
# KT&G:105,000원
# 우리금융지주:17,410원
# SK텔레콤:58,100원
# 기업은행:15,560원
# 삼성중공업:14,040원
# KT:47,450원
# 카카오뱅크:23,800원
# LG:70,200원
# 포스코퓨처엠:141,700원
# SK:149,200원
# 삼성전기:142,100원
# 하이브:251,500원
# 한미반도체:104,600원
# 삼성에스디에스:130,500원
# 유한양행:123,500원
# 현대글로비스:128,200원
