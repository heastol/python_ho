# 워드클라우드
wordcloud = WordCloud(width = 800, height = 400, background_color = 'white').generate(text)

# 시각화
plt.figure(figsize = (10, 5))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.savefig("word1.png")
plt.show()

# %%
# 필요한 라이브러리 가져오기
import matplotlib.pyplot as plt # 데이터 시각화를 위한 라이브러리
from wordcloud import WordCloud # 워드 클라우드를 생성하는 라이브러리
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리하기

# 한글 폰트 설정
font_path = "./ref/D2Coding-Ver1.3.2-20180524.ttf"

# 분석할 텍스트 초기화
text ="""
국내 연구팀이 차세대 배터리인 무음극배터리의 수명과 안전성 문제를 해결할 수 있는 신소재를 개발하고 성능을 입증하는 데 성공했다.
한국원자력연구원은 충남대, 경북대 연구팀과 협력해 미세한 은 입자를 주입한 맥신 복합체 소재를 개발하고 무음극배터리의 안정성을 강화했다고 27일 밝혔다. 맥신은 탄소(C)와 티타늄(Ti)으로 이뤄진 얇은 층으로 구성된 소재로 금속처럼 전기를 잘 전달하면서도 유연한 소재다. 연구결과는 국제학술지 '물리화학 레터스'에 공개됐다.
무음극배터리는 기존 배터리에서 음극을 제거해 작고 가벼우면서도 에너지 저장용량을 늘린 차세대 배터리다. 전기차나 에너지저장장치 등 높은 에너지밀도와 경량화가 필요한 분야에서 주목하고 있다.
무음극배터리는 배터리 내부 이온이 고르게 이동하지 않아 금속이 불규칙하고 뾰족하게 증착되는 수지상돌기가 쉽게 형성돼 배터리 수명과 안전성이 저하되는 문제가 있다.
연구팀은 기존 맥신 소재만으로는 배터리 내 이온 흐름이 원활하지 않다는 점을 개선하기 위해 맥신 층 사이에 미세한 은 입자를 삽입한 복합체를 개발했다. 은 입자는 전기전도성이 높고 경제적인 물질이다.
맥신과 은 입자는 모두 음전하(-)를 띠며 서로 밀어내기 때문에 주입이 어렵다. 연구팀은 이 문제를 압력 차이로 해결했다. 맥신 내부 압력을 낮춰 대기압이 은 입자를 맥신 층 사이로 밀어 넣도록 한 것이다.
맥신과 은 복합체를 배터리 내부에서 이온이 저장되는 금속판 위에 도포한 결과 이온의 이동 통로 넓이가 10배 이상 커져 이온이 배터리 내부에 고르게 흘러 들어간다는 사실이 확인됐다. 이온 흐름이 균일하면 수지상돌기 형성이 줄어 배터리 성능과 안전성이 향상된다.
연구팀은 원자력연 중성자 소각산란장치를 활용해 배터리 내 맥신 복합체가 이온 흐름을 원활히 한다는 사실을 확인했다. 전기전도도를 측정해 맥신 복합체를 삽입한 무음극배터리가 정상 작동한다는 것도 확인했다.
중성자 소각산란장치는 냉중성자원을 샘플에 조사하고 튕겨 나온 중성자를 통해 물질의 배치나 구조 등을 정밀하게 분석하는 장치다. 냉중성자는 연구용원자로인 하나로에서 생산된 고온의 중성자를 극저온까지 식힌 중성자로 나노미터 크기의 물질 구조를 연구하는 데 활용된다.
논문 제1저자인 참여한 이상호 원자력연 중성자과학부 선임연구원은 "맥신과 같은 2차원 소재의 미세 경로 조절 기술은 무음극전지에서 안전성과 수명을 연장하는 핵심기술로 향후 이차전지 연구에 다양성을 제공할 것으로 기대된다"고 전했다.
""" # wordcloud에서 사용할 텍스트 문자열 (여기에 사용할 텍스트를 넣으세요)


# data = [t for t in text if bool(t.strip())]
# print(data)
komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)


# 워드 클라우드 생성
# WordCloud 객체를 생성할 때의 매개변수:
# width=800: 워드 클라우드의 너비를 800 픽셀로 설정
# height=400: 워드 클라우드의 높이를 400 픽셀로 설정
# background_color='white': 워드 클라우드의 배경색을 흰색으로 설정
wordcloud = WordCloud(font_path= font_path, width=800, height=400, background_color='white').generate(nouns_text)

# 시각화
plt.figure(figsize=(10,5)) # 시각화할 그림 크기를 설정 (가로 10인치, 세로 5인치)
plt.imshow(wordcloud, interpolation="bilinear") # 생성된 워드 클라우드를 그림으로 표시
plt.axis('off') # x, y 축을 표시하지 않도록 설정
plt.savefig("word2.png")
plt.show() # 그림을 화면에 표시
# Out:
# 국내 연구 팀 차세대 배터리 무음 극 배터리 수명 안전 문제 해결 수 신소재 개발 성능 입증 데 성공 한국원자력연구원 충남대 경북대 연구 팀 협력 은 입자 주입 맥 신 복합체 소재 개발 무음 극 배터리 안정 강화 일 맥 신 탄소 층 구성 소재 금속 전기 전달 소재 연구 결과 국제 학술지 물리화학 공개 무음 극 배터리 기존 배터리 음 극 제거 에너지 저장 용량 차세대 배터리 기차 에너지 저장 장치 등 에너지 밀도 경량 필요 분야 주목 무음 극 배터리 배터리 내부 이온 이동 금속 불규칙 증착 수 지상 돌 기가 형성 배터리 수명 안전 저하 문제 연구 팀 기존 맥 신 소재 배터리 이온 흐름 원활 점 개선 맥 신 층 사이 은 입자 삽입 복합체 개발 은 입자 전기 전도성 경제 물질 맥 신 은 입자 음 전하 밀어내기 때문 주입 연구 팀 문제 압력 차이 해결 맥 신 내부 압력 대기압 은 입자 맥 신 층 사이 밀어 것 맥 신 은 복합체 배터리 내부 이온 저장 금속 판 위 도포 결과 이온 이동 통로 넓이 배 이상 이온 배터리 내부 사실 확인 이온 흐름 균일 수지 형성 배터리 성능 안전 향상 연구 팀 원자력연 중성자 소각 산란 장치 활용 배터리 맥 신 복합체 이온 흐름 사실 확인 전기전도도 측정 맥 신 복합체 삽입 무음 극 배터리 정상 작동 것 확인 중성자 소각 산란 장치 냉 중성자 원 샘플 조사 중성자 물질 배치 구조 등 정밀 분석 장치 냉 중성자 연구 용 원자로 하나로 생산 고온 중성자 극 온 중성자 나노미터 크기 물질 구조 연구 데 활용 논문 저자 참여 이상호 원자력연 중성자 과학부 선임 연구원 맥 신 2차원 소재 미세 경로 조절 기술 무음 극 전지 안전 수명 연장 핵심 기술 향후 이차 전지 연구 다양성 제공 것 기대

# %%
# 필요한 라이브러리 가져오기
import matplotlib.pyplot as plt # 데이터 시각화를 위한 라이브러리
from wordcloud import WordCloud # 워드 클라우드 생성하는 라이브러리
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리하기

# 한글 폰트 설정
font_path = './ref/D2Coding-Ver1.3.2-20180524.ttf'

# 분석할 텍스트 초기화
text = """
세종실록24권, 세종 6년 6월
양녕 대군에게 소주와 내수를 하사하다
환자 김부·윤덕인의 직첩을 돌려주도록 명하다
예조에서 중국 사신의 건어물 무역 의뢰와 그 수급에 관해 아뢰다
경상도 주전 별감 백환이 새로 만든 돈 20관을 바치다
영의정 유정현 등을 불러 부묘 의주·존호·중 지운에 관해 논의하고 전교하다
포로된 중국인 장청 등 남녀 14명에게 각각 옷·갓·신·버선 등을 하사하다
정사를 보다
경상도 주전 별감 하담이 새로 만든 돈 10관을 바치다
왕실의 족파라 하는 자들의 세계를 상세히 핵문하여 알리라고 함길도에 전지하다
중국인 장청 등 남녀 14명을 요동으로 보내어 놓아주다
중 지운을 참형에 처하고 가산을 적몰하다
명나라 사신 왕현이 의주에 도착하니 원접사 이맹균으로 맞이하게 하다
정사를 보다
경녕군 이비에게 출입을 허가하고, 구사를 돌려주도록 명하다
성절사 예조 판서 신상이 경사에서 돌아오다
모자라거나 망비·도용된 의창 곡식 등의 보충 방안에 관한 호조의 계
삼한 국대부인 송씨의 졸기
삼한 국대부인 송씨의 예장 등의 일을 정선 공주의 예에 따르도록 하다
광효전에 둘 위판독을 《주문공가례》의 신주좌 제도에 따르도록 하다
종묘 환조·태조실 악장의 ’황조’·’황고’를 ’현조’·’황조’로 하기를 청한 예조의 계
원경 왕후에게 ‘창덕 소열’의 존호를 더 올리다
이직·허조 등이 원경 왕후의 존호를 신주·옥책에 봉헌하는 것에 관해 논의하다
명나라 사신의 영접례에 관한 예조의 계
예조에서 광효전과 헌릉 삭망제에 유백병을 쓰기를 청하다
흠문 기거사 중군 동지총제 현귀명이 가지고 간 주본
평안도 각 익 소속 군정의 다소와 거리의 원근 조정에 관한 이조의 계
호조에서 제용감에 납부하는 신세포의 상납 조정에 관해 아뢰다
최세온을 참형할 것을 청한 사헌부의 계. 최세온의 아들 이기가 신문고로 호소하다
삼한 국대부인 송씨 집에 행차하여 곡림하는 예를 의식대로 거행하다
사헌부 지평 이견기가 이종무의 부처 문제에 대해 아뢰다
의창 조곡의 출납을 거짓 보고한 수령들의 처벌에 대한 대사헌 유영 등의 상소문
태종의 신주를 부묘하는 의주에 관한 예조의 계
환자곡의 출납을 거짓 보고한 수령들의 논죄율을 의논하다. 유영 등이 사직을 청하다
황해도 은율 현감 주의가 물고함에 따른 부물을 내리도록 청한 예조의 계
정사를 보다
환자곡 출납의 보고와 수령들에 관해 논의하고, 유영 등의 소장을 형조에게 이관하다
제주 자제가 사사로이 진상하는 말은 오는 대로 값을 주라고 전지하다
""" # wordcloud에서 사용할 텍스트 문자열 (여기에 사용할 텍스트를 넣으세요)

# data = [t for t in text if bool(t.strip())]
komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)




# 워드클라우드
# WordCloud 객체를 생성할 때의 매개변수
# width = 800 워드 클라우드의 너비를 800 픽셀로 설정
# height = 400 워드 클라우드의 높이를 400 픽셀로 설정
# background_color = 'white' 워드 클라우드의 배경색을 흰색으로 설정
wordcloud = WordCloud(font_path = font_path, width = 800, height = 400, background_color = 'white').generate(nouns_text)

# 시각화
plt.figure(figsize = (10, 5)) # 시각화할 그림 크기를 설정 (가로 10인치, 세로 5인치)
plt.imshow(wordcloud, interpolation = "bilinear") # 생성된 워드 클라우드를 그림으로 표시
plt.axis('off') # x, y 축을 표시하지 않도록 설정
plt.savefig("word3.png")
plt.show() # 그림을 화면에 표시
# Out:
# 세종실록 24 권 세종 년 6월 대군 소주 내수 하사 환자 김 부 윤 덕인 직 첩 예조 중국 사신 건어물 무역 의뢰 수급 경상도 주전 별감 백화 돈 관 영의정 유정현 등 부묘 의주 존호 중 지운 논의 전교 포로 중국인 장청 등 남녀 명 옷 갓 신 버선 등 하사 정사 경상도 주전 별감 돈 관 왕실 족 파라 자 세계 핵 문 함 길 전지 중국인 장청 등 남녀 명 요동 중 지운 참형 가산 적 몰 명나라 사신 왕현 의주 도착 원 접사 균 정사 경녕군 이비 출입 허가 구사 성 절사 예조 판서 신상 경사 망 비 도용 의창 곡식 등 보충 방안 호조 계 삼한 국대부인 송 씨 삼한 국대부인 송 씨 예장 등 일 정선 공주 예 광 효 전 위 판독 주문공가례 신주 좌 제도 종묘 환조 태조 실 악장 황조 황 현 조 황조 예조 계 원경 왕후 창덕 열 존호 이직 허조 등 원경 왕후 존호 신주 옥 책 봉헌 것 논의 명나라 사신 예조 계 예조 광 효 전과 헌릉 삭망 유백 병 흠 문 기거 사 중구 동지 총 귀 명 간 주보 평안도 익 소속 군정 다소 거리 원근 조정 이조 계 호조 용감 납부 세포 상납 조정 최 세 온 참형 것 사헌부 계 최 세 온 아들 이기 신문고 호소 삼한 국대부인 송 씨 집 행차 곡 림 예 의식 거행 사헌부 지평 이견 기가 이종무 부처 문제 의창 조곡 출 납 거짓 보고 수령 처벌 대사헌 유영 등 상소문 태종 신주 부묘 의주 예조 계 환자 곡 출 납 거짓 보고 수령 논 죄 의논 유영 등 사직 황해도 은유 현감 주의 물 고함 부물 예조 계 정사 환자 곡 출 납 보고 수령 논의 유영 등 소장 형조 이관 제주 자제 사사 로이 진상 말 대로 값 전지 삼한 국대부인 송 씨 치전 제문 일본국 구주 원 의주 토산물 일본국 석성 관사 평 만 토산물 양 자 첨 절 제사 이징옥 공적 함 길 경 차관 이숙 회계 언 참형 즈음 용서 유정현 등 율 한확 어미 사제 흠 차 사신 영접 의주 환자 곡 출 납 거짓 보고 관련 수령 처벌 우사 간 이반 등 상소
, '도안': 1, '무사': 1, '대마': 1, '사노': 1, '막': 1, '금': 1, '교수형': 1, '감': 1, '한성부': 1, '도성': 1, '안팎': 1, '금지': 1, '구역': 1, '암': 1, '철거': 1, '각도': 1, '병마': 1, '겸직': 1, '칙': 1, '주문': 1, '원민': 1, '급': 1, '진': 1, '벽': 1, '복': 1, '주장': 1, '이발': 1, '전라도': 1, '유문': 1, '강원도': 1, '모화': 1, '루': 1, '다례': 1, '하': 1, '마연': 1, '두목': 1, '인': 1, '안장': 1, '거': 1, '둥': 1, '익일': 1, '연': 1, '교외': 1, '사람': 1, '농사': 1, '형편': 1, '동궁': 1, '잔치': 1, '판': 1, '우': 1, '군도': 1, '부사': 1, '경원': 1, '합의': 1, '무리': 1, '위문': 1, '견': 1, '싯가': 1, '건어': 1, '사시': 1, '납일': 1, '명절': 1, '향': 1, '정전': 1, '남쪽': 1, '악': 1, '행례': 1, '삭제': 1, '포': 1, '마': 1, '담제': 1, '참여': 1, '이천': 1, '현사': 1})

# %%
word = ['안녕', '하세요', '안녕', '할까요', '안녕', '하세요']
word = " ".join(word)
print(word)
# Out:
# 안녕 하세요 안녕 할까요 안녕 하세요

# %%
word = """
지난달 김해국제공항 발생한 에어부산 여객기 화재는 출발 지연이 결정되고 10분 뒤 시작된 것으로 조사됐다.
발화지점으로 지목된 수화물 선반은 불에 녹아 형체를 알 수 없는 것으로 확인됐다.
국토교통부 항공철도사고조사위원회(항철위)는 이 같은 사고 개요 등을 포함한 A4용지 6장 분량의 예비보고서를 발간했다고 27일 밝혔다.
이번 보고서는 사고 이후 항철위가 처음으로 공표한 정식 조사 보고서로 사고 개요가 담겨 있고 화재 원인 등은 포함 돼 있지 않다.
예비보고서는 사고 조사 당국이 국제민간항공협약에 따라 초기 조사 상황 공유 차원에서 사고 발생 30일 이내에 국제민간항공기구(ICAO)와 사고 관련국에 보내도록 규정돼 있다.
보고서에 따르면 지난달 28일 김해국제공항을 통해 부산에서 홍콩으로 향할 예정인 에어부산 BX391편은 9시 55분 출발 예정이었다.
항공기 문을 완전히 닫고 램프에서 출발 대기중이던 항공기는오후 10시 4분 관제사가 기장에게 '항로상 간격 분리(안전거리 확보)'를 지시하며 출발 예정 시간이 오후 10시 33분으로 늦춰졌다.
곧바로 기장은 지상 요원에게 오후 10시 30분에 푸시백(견인차를 이용해 탑승게이트에서 항공기를 뒤로 움직이는 작업)을 준비하라고 지시하고 승객들에게 출발 지연 소식을 알렸다.
화재는 항공기 출발 지연 결정이 내려진 10분 뒤인 오후 10시 14분 발생한 것으로 조사됐다.
조종실에 'LAV Smoke(객실 내 연기)' 경고가 있었고, 잠시 후 객실 승무원이 객실 화재 상황을 기장에게 보고했다.
기장은 화재 감지 1분 뒤인 10시 15분께 곧장 객실 사무장과 승객들에게 비상 탈출을 지시했다.
이후 화재로 인한 승객 대피 상황을 관계기관에 보고한 기장은 모든 승객이 대피했는지 확인 후 항공기에서 마지막으로 탈출했다는 내용이 보고서에 담겼다.
다만 이같은 사고 개요는 에어부산 측 진술과 초기 조사 내용에 근거해 작성됐다.
화재 진압은 오후 10시 20분께 본격적으로 시작돼 오후 11시 31분에 완료됐다.
소방당국은 7명을 경상으로 분류했는데 항철위는 중상 3명, 경상 24명으로 부상자를 분류했다.
보고서에는 총 3장의 항공기 사진이 담겨 있으며 발화지점으로 지목되는 수화물 선반이 전부 타 형체를 알 수 없는 내부 사진도 공개됐다.
항철위는 화재 감식, 비행자료기록장치(FDR), 조종실음성기록장치(CVR) 자료 분석, 항공 교통 관제 데이터, 항공기 부품 검사, 탑승객 인터뷰, 지상 승무원 증언 등을 종합해 사고 분석을 진행하고 있다.
자세한 사고 원인이 담기는 최종보고서는 1년 가량 걸릴 것으로 예상된다."""

words = word.split()

word_counts = {}

for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

for word, count in word_counts.items():
    print(f"{word} : {count}")
# Out:
# 지난달 : 2
# 김해국제공항 : 1
# 발생한 : 2
# 에어부산 : 3
# 여객기 : 1
# 화재는 : 2
# 출발 : 6
# 지연이 : 1
# 결정되고 : 1
# 10분 : 2
# 뒤 : 1
# 시작된 : 1
# 것으로 : 4
# 조사됐다. : 2
# 발화지점으로 : 2
# 지목된 : 1
# 수화물 : 2
# 선반은 : 1
# 불에 : 1
# 녹아 : 1
# 형체를 : 2
# 알 : 2
# 수 : 2
# 없는 : 2
# 확인됐다. : 1
# 국토교통부 : 1
# 항공철도사고조사위원회(항철위)는 : 1
# 이 : 1
# 같은 : 1
# 사고 : 9
# 개요 : 1
# 등을 : 2
# 포함한 : 1
# A4용지 : 1
# 6장 : 1
# 분량의 : 1
# 예비보고서를 : 1
# 발간했다고 : 1
# 27일 : 1
# 밝혔다. : 1
# 이번 : 1
# 보고서는 : 1
# 이후 : 2
# 항철위가 : 1
# 처음으로 : 1
# 공표한 : 1
# 정식 : 1
# 조사 : 4
# 보고서로 : 1
# 개요가 : 1
# 담겨 : 2
# 있고 : 1
# 화재 : 5
# 원인 : 1
# 등은 : 1
# 포함 : 1
# 돼 : 1
# 있지 : 1
# 않다. : 1
# 예비보고서는 : 1
# 당국이 : 1
# 국제민간항공협약에 : 1
# 따라 : 1
# 초기 : 2
# 상황 : 1
# 공유 : 1
# 차원에서 : 1
# 발생 : 1
# 30일 : 1
# 이내에 : 1
# 국제민간항공기구(ICAO)와 : 1
# 관련국에 : 1
# 보내도록 : 1
# 규정돼 : 1
# 있다. : 2
# 보고서에 : 2
# 따르면 : 1
# 28일 : 1
# 김해국제공항을 : 1
# 통해 : 1
# 부산에서 : 1
# 홍콩으로 : 1
# 향할 : 1
# 예정인 : 1
# BX391편은 : 1
# 9시 : 1
# 55분 : 1
# 예정이었다. : 1
# 항공기 : 4
# 문을 : 1
# 완전히 : 1
# 닫고 : 1
# 램프에서 : 1
# 대기중이던 : 1
# 항공기는오후 : 1
# 10시 : 6
# 4분 : 1
# 관제사가 : 1
# 기장에게 : 2
# '항로상 : 1
# 간격 : 1
# 분리(안전거리 : 1
# 확보)'를 : 1
# 지시하며 : 1
# 예정 : 1
# 시간이 : 1
# 오후 : 5
# 33분으로 : 1
# 늦춰졌다. : 1
# 곧바로 : 1
# 기장은 : 3
# 지상 : 2
# 요원에게 : 1
# 30분에 : 1
# 푸시백(견인차를 : 1
# 이용해 : 1
# 탑승게이트에서 : 1
# 항공기를 : 1
# 뒤로 : 1
# 움직이는 : 1
# 작업)을 : 1
# 준비하라고 : 1
# 지시하고 : 1
# 승객들에게 : 2
# 지연 : 2
# 소식을 : 1
# 알렸다. : 1
# 결정이 : 1
# 내려진 : 1
# 뒤인 : 2
# 14분 : 1
# 조종실에 : 1
# 'LAV : 1
# Smoke(객실 : 1
# 내 : 1
# 연기)' : 1
# 경고가 : 1
# 있었고, : 1
# 잠시 : 1
# 후 : 2
# 객실 : 3
# 승무원이 : 1
# 상황을 : 2
# 보고했다. : 1
# 감지 : 1
# 1분 : 1
# 15분께 : 1
# 곧장 : 1
# 사무장과 : 1
# 비상 : 1
# 탈출을 : 1
# 지시했다. : 1
# 화재로 : 1
# 인한 : 1
# 승객 : 1
# 대피 : 1
# 관계기관에 : 1
# 보고한 : 1
# 모든 : 1
# 승객이 : 1
# 대피했는지 : 1
# 확인 : 1
# 항공기에서 : 1
# 마지막으로 : 1
# 탈출했다는 : 1
# 내용이 : 1
# 담겼다. : 1
# 다만 : 1
# 이같은 : 1
# 개요는 : 1
# 측 : 1
# 진술과 : 1
# 내용에 : 1
# 근거해 : 1
# 작성됐다. : 1
# 진압은 : 1
# 20분께 : 1
# 본격적으로 : 1
# 시작돼 : 1
# 11시 : 1
# 31분에 : 1
# 완료됐다. : 1
# 소방당국은 : 1
# 7명을 : 1
# 경상으로 : 1
# 분류했는데 : 1
# 항철위는 : 2
# 중상 : 1
# 3명, : 1
# 경상 : 1
# 24명으로 : 1
# 부상자를 : 1
# 분류했다. : 1
# 보고서에는 : 1
# 총 : 1
# 3장의 : 1
# 사진이 : 1
# 있으며 : 1
# 지목되는 : 1
# 선반이 : 1
# 전부 : 1
# 타 : 1
# 내부 : 1
# 사진도 : 1
# 공개됐다. : 1
# 감식, : 1
# 비행자료기록장치(FDR), : 1
# 조종실음성기록장치(CVR) : 1
# 자료 : 1
# 분석, : 1
# 항공 : 1
# 교통 : 1
# 관제 : 1
# 데이터, : 1
# 부품 : 1
# 검사, : 1
# 탑승객 : 1
# 인터뷰, : 1
# 승무원 : 1
# 증언 : 1
# 종합해 : 1
# 분석을 : 1
# 진행하고 : 1
# 자세한 : 1
# 원인이 : 1
# 담기는 : 1
# 최종보고서는 : 1
# 1년 : 1
# 가량 : 1
# 걸릴 : 1
# 예상된다. : 1
